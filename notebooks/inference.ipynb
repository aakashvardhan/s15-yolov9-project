# %%
# %cd ..
# Out:
# /Users/aakashvardhan/Library/CloudStorage/GoogleDrive-vardhan.aakash1@gmail.com/My Drive/ERA v2/s15-yolov9-project
# /Users/aakashvardhan/.pyenv/versions/3.11.0/envs/myproject/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pwd
# Out:
# /Users/aakashvardhan/Library/CloudStorage/GoogleDrive-vardhan.aakash1@gmail.com/My Drive/ERA v2/s15-yolov9-project

# %% [markdown]
# ## Detecting GUI elements in a screenshot

# %%
# !python yolov9/detect_dual.py --source yolov9/data/sketch_images/valid/images/1EACABD4-EF65-46D0-82D3-F01EDCCA4992_png.rf.b6ff1482b613270be937c736f62be716.jpg --img 640 --device cpu --weights yolov9/runs/train/exp2/weights/best.pt --name gui_output
# Out:
# detect_dual: weights=['yolov9/runs/train/exp2/weights/best.pt'], source=yolov9/data/sketch_images/valid/images/1EACABD4-EF65-46D0-82D3-F01EDCCA4992_png.rf.b6ff1482b613270be937c736f62be716.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=gui_output, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/Users/aakashvardhan/Library/CloudStorage/GoogleDrive-vardhan.aakash1@gmail.com/My': No such file or directory
# YOLO 🚀 2024-7-12 Python-3.11.0 torch-2.1.2 CPU
#
# Fusing layers...
# yolov9-e summary: 839 layers, 68558608 parameters, 0 gradients
# ...

# %%
from IPython.display import Image

Image(filename='yolov9/runs/detect/gui_output/1EACABD4-EF65-46D0-82D3-F01EDCCA4992_png.rf.b6ff1482b613270be937c736f62be716.jpg')

# %%
# !python yolov9/detect_dual.py --source yolov9/data/Shipping-1.png --img 640 --device cpu --weights yolov9/runs/train/exp2/weights/best.pt --name gui_output2
# Out:
# detect_dual: weights=['yolov9/runs/train/exp2/weights/best.pt'], source=yolov9/data/Shipping-1.png, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=gui_output2, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/Users/aakashvardhan/Library/CloudStorage/GoogleDrive-vardhan.aakash1@gmail.com/My': No such file or directory
# YOLO 🚀 2024-7-12 Python-3.11.0 torch-2.1.2 CPU
#
# Fusing layers...
# yolov9-e summary: 839 layers, 68558608 parameters, 0 gradients
# ...

# %%
Image(filename='yolov9/runs/detect/gui_output2/Shipping-1.png')
